# %%
# imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from my_nn.data.sample_data import generate_data, plot_data, save_data

# %% [markdown]
# #### This notebook is to see what the data sets we want to use look like. There are 4 targets defined for the same feature set X. One is a binary classification with a parabolic boundary. The second is a binary classification with a piecewise linear boundary. The third is a multiclass classification with a 2 branch hyperbolic decision boundary, and the 4th is a regression with z = x<sup>2</sup> + y <sup>2</sup>

# %%
# generate all the data sets
df, target_cols = generate_data(seed=42)

# %%
for target in target_cols:
    plot_data(df, target=target, sample = len(df))
